# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
col_names=['pregnant','Plasma_glucose','bp','skin_fold','insulin','mass_index','pedigree','age','class']
df= pd.read_csv('pima-indians-diabetes.csv',names=col_names)

# %%
df.drop(df.index[:9],inplace=True)

# %%
errors = {'coerce','raise'}
df = df.apply(pd.to_numeric,errors = 'coerce')

# %%
df.isnull().sum()
df.dropna()
# Out:
#      pregnant  Plasma_glucose    bp  skin_fold  insulin  mass_index  pedigree  \
# 9           6           148.0  72.0       35.0      0.0        33.6     0.627
# 10          1            85.0  66.0       29.0      0.0        26.6     0.351
# 11          8           183.0  64.0        0.0      0.0        23.3     0.672
# 12          1            89.0  66.0       23.0     94.0        28.1     0.167
# 13          0           137.0  40.0       35.0    168.0        43.1     2.288
# ..        ...             ...   ...        ...      ...         ...       ...
# 772        10           101.0  76.0       48.0    180.0        32.9     0.171
# 773         2           122.0  70.0       27.0      0.0        36.8     0.340
# 774         5           121.0  72.0       23.0    112.0        26.2     0.245
# 775         1           126.0  60.0        0.0      0.0        30.1     0.349
# 776         1            93.0  70.0       31.0      0.0        30.4     0.315
#
#       age  class
# 9    50.0    1.0
# 10   31.0    0.0
# 11   32.0    1.0
# 12   21.0    0.0
# 13   33.0    1.0
# ..    ...    ...
# 772  63.0    0.0
# 773  27.0    0.0
# 774  30.0    0.0
# 775  47.0    1.0
# 776  23.0    0.0
#
# [768 rows x 9 columns]

# %%
y=df['class']
X=df.drop('class',axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=0.2,random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators=100, 
                               bootstrap = True,
                               max_features = 'sqrt')
rf_model.fit(X_train,y_train)
y_pred=rf_model.predict(X_test)
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
print ("Accuracy : ", 
    accuracy_score(y_test,y_pred)*100)
# Out:
# [[95 12]
#  [17 30]]
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.89      0.87       107
#          1.0       0.71      0.64      0.67        47
#
#     accuracy                           0.81       154
#    macro avg       0.78      0.76      0.77       154
# weighted avg       0.81      0.81      0.81       154
#
# Accuracy :  81.16883116883116

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=5)
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
print ("Accuracy : ", 
    accuracy_score(y_test,y_pred)*100)
# Out:
# [[88 19]
#  [13 34]]
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.82      0.85       107
#          1.0       0.64      0.72      0.68        47
#
#     accuracy                           0.79       154
#    macro avg       0.76      0.77      0.76       154
# weighted avg       0.80      0.79      0.80       154
#
# Accuracy :  79.22077922077922

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=9)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
print ("Accuracy : ", 
    accuracy_score(y_test,y_pred)*100)
# Out:
# [[90 17]
#  [18 29]]
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.84      0.84       107
#          1.0       0.63      0.62      0.62        47
#
#     accuracy                           0.77       154
#    macro avg       0.73      0.73      0.73       154
# weighted avg       0.77      0.77      0.77       154
#
# Accuracy :  77.27272727272727

# %%
#ANN

# %%
import tensorflow as tf

# %%
model =tf.keras.models.Sequential([
          tf.keras.layers.Dense(64,activation='relu',input_shape=(8,)),
          tf.keras.layers.Dense(128,activation='relu'),
          tf.keras.layers.Dense(128,activation='relu'),
          tf.keras.layers.Dropout(0.2),
          tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
model.fit(X_train, y_train,epochs = 100,batch_size=32)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 614 samples
# Epoch 1/100
# 614/614 [==============================] - 0s 396us/sample - loss: 2.2557 - accuracy: 0.5668
# Epoch 2/100
# 614/614 [==============================] - 0s 88us/sample - loss: 1.3482 - accuracy: 0.5847
# Epoch 3/100
# 614/614 [==============================] - 0s 94us/sample - loss: 1.0955 - accuracy: 0.5668
# Epoch 4/100
# 614/614 [==============================] - 0s 96us/sample - loss: 0.7892 - accuracy: 0.6270
# Epoch 5/100
# 614/614 [==============================] - 0s 84us/sample - loss: 0.7387 - accuracy: 0.6466
# Epoch 6/100
# 614/614 [==============================] - 0s 94us/sample - loss: 0.6577 - accuracy: 0.6743
# Epoch 7/100
# 614/614 [==============================] - 0s 87us/sample - loss: 0.6553 - accuracy: 0.6482
# Epoch 8/100
# 614/614 [==============================] - 0s 86us/sample - loss: 0.6098 - accuracy: 0.6629
# Epoch 9/100
# 614/614 [==============================] - 0s 139us/sample - loss: 0.6063 - accuracy: 0.6889
# Epoch 10/100
# 614/614 [==============================] - 0s 129us/sample - loss: 0.6721 - accuracy: 0.6645
# Epoch 11/100
# 614/614 [==============================] - 0s 86us/sample - loss: 0.5804 - accuracy: 0.6906
# Epoch 12/100
# 614/614 [==============================] - 0s 115us/sample - loss: 0.5856 - accuracy: 0.6922
# Epoch 13/100
# 614/614 [==============================] - 0s 110us/sample - loss: 0.5992 - accuracy: 0.7117
# Epoch 14/100
# 614/614 [==============================] - 0s 100us/sample - loss: 0.6207 - accuracy: 0.6889
# Epoch 15/100
# 614/614 [==============================] - 0s 107us/sample - loss: 0.6281 - accuracy: 0.6694
# Epoch 16/100
# 614/614 [==============================] - 0s 101us/sample - loss: 0.6103 - accuracy: 0.6743
# Epoch 17/100
# 614/614 [==============================] - 0s 87us/sample - loss: 0.5799 - accuracy: 0.6857
# Epoch 18/100
# 614/614 [==============================] - 0s 79us/sample - loss: 0.5839 - accuracy: 0.6726
# Epoch 19/100
# 614/614 [==============================] - 0s 125us/sample - loss: 0.5693 - accuracy: 0.7117
# Epoch 20/100
# 614/614 [==============================] - 0s 142us/sample - loss: 0.5673 - accuracy: 0.7166
# Epoch 21/100
# 614/614 [==============================] - 0s 166us/sample - loss: 0.5576 - accuracy: 0.7101
# Epoch 22/100
# 614/614 [==============================] - 0s 236us/sample - loss: 0.5677 - accuracy: 0.7101
# Epoch 23/100
# 614/614 [==============================] - 0s 97us/sample - loss: 0.5704 - accuracy: 0.6906
# Epoch 24/100
# 614/614 [==============================] - 0s 103us/sample - loss: 0.5642 - accuracy: 0.7068
# Epoch 25/100
# 614/614 [==============================] - 0s 102us/sample - loss: 0.5483 - accuracy: 0.7199
# Epoch 26/100
# 614/614 [==============================] - 0s 138us/sample - loss: 0.5419 - accuracy: 0.7215
# Epoch 27/100
# 614/614 [==============================] - 0s 111us/sample - loss: 0.5407 - accuracy: 0.7313
# Epoch 28/100
# 614/614 [==============================] - 0s 105us/sample - loss: 0.5542 - accuracy: 0.7101
# Epoch 29/100
# 614/614 [==============================] - 0s 101us/sample - loss: 0.5549 - accuracy: 0.7101
# Epoch 30/100
# 614/614 [==============================] - 0s 95us/sample - loss: 0.5587 - accuracy: 0.6889
# Epoch 31/100
# 614/614 [==============================] - 0s 101us/sample - loss: 0.5980 - accuracy: 0.6873
# Epoch 32/100
# 614/614 [==============================] - 0s 101us/sample - loss: 0.5510 - accuracy: 0.7231
# Epoch 33/100
# 614/614 [==============================] - 0s 98us/sample - loss: 0.5450 - accuracy: 0.7150
# Epoch 34/100
# 614/614 [==============================] - 0s 128us/sample - loss: 0.5448 - accuracy: 0.7231
# Epoch 35/100
# 614/614 [==============================] - 0s 129us/sample - loss: 0.5340 - accuracy: 0.7150
# Epoch 36/100
# 614/614 [==============================] - 0s 127us/sample - loss: 0.5414 - accuracy: 0.7085
# Epoch 37/100
# 614/614 [==============================] - 0s 186us/sample - loss: 0.5534 - accuracy: 0.7166
# Epoch 38/100
# 614/614 [==============================] - 0s 92us/sample - loss: 0.5384 - accuracy: 0.7313
# Epoch 39/100
# 614/614 [==============================] - 0s 112us/sample - loss: 0.5261 - accuracy: 0.7280
# Epoch 40/100
# 614/614 [==============================] - 0s 121us/sample - loss: 0.5305 - accuracy: 0.7215
# Epoch 41/100
# 614/614 [==============================] - 0s 107us/sample - loss: 0.5367 - accuracy: 0.7313
# Epoch 42/100
# 614/614 [==============================] - 0s 102us/sample - loss: 0.5547 - accuracy: 0.6922
# Epoch 43/100
# 614/614 [==============================] - 0s 94us/sample - loss: 0.5367 - accuracy: 0.7264
# Epoch 44/100
# 614/614 [==============================] - 0s 85us/sample - loss: 0.5337 - accuracy: 0.7427
# Epoch 45/100
# 614/614 [==============================] - 0s 95us/sample - loss: 0.5418 - accuracy: 0.7248
# Epoch 46/100
# 614/614 [==============================] - 0s 134us/sample - loss: 0.5291 - accuracy: 0.7508
# Epoch 47/100
# 614/614 [==============================] - 0s 134us/sample - loss: 0.5187 - accuracy: 0.7492
# Epoch 48/100
# 614/614 [==============================] - 0s 128us/sample - loss: 0.5533 - accuracy: 0.7085
# Epoch 49/100
# 614/614 [==============================] - 0s 127us/sample - loss: 0.5210 - accuracy: 0.7313
# Epoch 50/100
# 614/614 [==============================] - 0s 128us/sample - loss: 0.5318 - accuracy: 0.7264
# Epoch 51/100
# 614/614 [==============================] - 0s 130us/sample - loss: 0.5217 - accuracy: 0.7524
# Epoch 52/100
# 614/614 [==============================] - 0s 128us/sample - loss: 0.5424 - accuracy: 0.7036
# Epoch 53/100
# 614/614 [==============================] - 0s 136us/sample - loss: 0.5321 - accuracy: 0.7248
# Epoch 54/100
# 614/614 [==============================] - 0s 164us/sample - loss: 0.5252 - accuracy: 0.7345
# Epoch 55/100
# 614/614 [==============================] - 0s 127us/sample - loss: 0.5395 - accuracy: 0.7215
# Epoch 56/100
# 614/614 [==============================] - 0s 143us/sample - loss: 0.5295 - accuracy: 0.7280
# Epoch 57/100
# 614/614 [==============================] - 0s 139us/sample - loss: 0.5196 - accuracy: 0.7443
# Epoch 58/100
# 614/614 [==============================] - 0s 122us/sample - loss: 0.5225 - accuracy: 0.7362
# Epoch 59/100
# 614/614 [==============================] - 0s 117us/sample - loss: 0.5169 - accuracy: 0.7296
# Epoch 60/100
# 614/614 [==============================] - 0s 128us/sample - loss: 0.5105 - accuracy: 0.7459
# Epoch 61/100
# 614/614 [==============================] - 0s 125us/sample - loss: 0.5035 - accuracy: 0.7476
# Epoch 62/100
# 614/614 [==============================] - 0s 138us/sample - loss: 0.5027 - accuracy: 0.7508
# Epoch 63/100
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4938 - accuracy: 0.7606
# Epoch 64/100
# 614/614 [==============================] - 0s 130us/sample - loss: 0.5239 - accuracy: 0.7329
# Epoch 65/100
# 614/614 [==============================] - 0s 138us/sample - loss: 0.5156 - accuracy: 0.7329
# Epoch 66/100
# 614/614 [==============================] - 0s 144us/sample - loss: 0.5180 - accuracy: 0.7345
# Epoch 67/100
# 614/614 [==============================] - 0s 147us/sample - loss: 0.5052 - accuracy: 0.7427
# Epoch 68/100
# 614/614 [==============================] - 0s 127us/sample - loss: 0.5017 - accuracy: 0.7329
# Epoch 69/100
# 614/614 [==============================] - 0s 134us/sample - loss: 0.5140 - accuracy: 0.7362
# Epoch 70/100
# 614/614 [==============================] - 0s 115us/sample - loss: 0.4905 - accuracy: 0.7508
# Epoch 71/100
# 614/614 [==============================] - 0s 109us/sample - loss: 0.5189 - accuracy: 0.7362
# Epoch 72/100
# 614/614 [==============================] - 0s 109us/sample - loss: 0.4995 - accuracy: 0.7345
# Epoch 73/100
# 614/614 [==============================] - 0s 100us/sample - loss: 0.4809 - accuracy: 0.7557
# Epoch 74/100
# 614/614 [==============================] - 0s 103us/sample - loss: 0.4900 - accuracy: 0.7557
# Epoch 75/100
# 614/614 [==============================] - 0s 110us/sample - loss: 0.4896 - accuracy: 0.7492
# Epoch 76/100
# 614/614 [==============================] - 0s 111us/sample - loss: 0.4909 - accuracy: 0.7459
# Epoch 77/100
# 614/614 [==============================] - 0s 105us/sample - loss: 0.4699 - accuracy: 0.7638
# Epoch 78/100
# 614/614 [==============================] - 0s 98us/sample - loss: 0.4603 - accuracy: 0.7655
# Epoch 79/100
# 614/614 [==============================] - 0s 98us/sample - loss: 0.4723 - accuracy: 0.7655
# Epoch 80/100
# 614/614 [==============================] - 0s 96us/sample - loss: 0.4811 - accuracy: 0.7622
# Epoch 81/100
# 614/614 [==============================] - 0s 168us/sample - loss: 0.4794 - accuracy: 0.7687
# Epoch 82/100
# 614/614 [==============================] - 0s 147us/sample - loss: 0.4849 - accuracy: 0.7508
# Epoch 83/100
# 614/614 [==============================] - 0s 150us/sample - loss: 0.4950 - accuracy: 0.7541
# Epoch 84/100
# 614/614 [==============================] - 0s 148us/sample - loss: 0.5075 - accuracy: 0.7459
# Epoch 85/100
# 614/614 [==============================] - 0s 154us/sample - loss: 0.4978 - accuracy: 0.7410 - loss: 0.4975 - accuracy: 0.73
# Epoch 86/100
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4746 - accuracy: 0.7769
# Epoch 87/100
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4846 - accuracy: 0.7655
# Epoch 88/100
# 614/614 [==============================] - 0s 155us/sample - loss: 0.4665 - accuracy: 0.7671
# Epoch 89/100
# 614/614 [==============================] - 0s 155us/sample - loss: 0.4601 - accuracy: 0.7622
# Epoch 90/100
# 614/614 [==============================] - 0s 146us/sample - loss: 0.4559 - accuracy: 0.7850
# Epoch 91/100
# 614/614 [==============================] - 0s 150us/sample - loss: 0.4691 - accuracy: 0.7573
# Epoch 92/100
# 614/614 [==============================] - 0s 195us/sample - loss: 0.4823 - accuracy: 0.7459
# Epoch 93/100
# 614/614 [==============================] - 0s 150us/sample - loss: 0.4635 - accuracy: 0.7818
# Epoch 94/100
# 614/614 [==============================] - 0s 165us/sample - loss: 0.4604 - accuracy: 0.7655
# Epoch 95/100
# 614/614 [==============================] - 0s 156us/sample - loss: 0.4657 - accuracy: 0.7704
# Epoch 96/100
# 614/614 [==============================] - 0s 151us/sample - loss: 0.4695 - accuracy: 0.7638
# Epoch 97/100
# 614/614 [==============================] - 0s 163us/sample - loss: 0.4627 - accuracy: 0.7769
# Epoch 98/100
# 614/614 [==============================] - 0s 163us/sample - loss: 0.4505 - accuracy: 0.7866
# Epoch 99/100
# 614/614 [==============================] - 0s 169us/sample - loss: 0.4446 - accuracy: 0.7850
# Epoch 100/100
# 614/614 [==============================] - 0s 171us/sample - loss: 0.4554 - accuracy: 0.7818

# %%
y_pred= model.evaluate(X_test,y_test)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# 154/154 [==============================] - 0s 606us/sample - loss: 0.5657 - accuracy: 0.7532
